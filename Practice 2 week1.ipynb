# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

data = {
    'Player': ['LeBron James', 'Kevin Durant', 'Stephen Curry', 'Nikola Jokic', 'Joel Embiid', 'Luka Doncic', 'Damian Lillard', 'Jayson Tatum'],
    'Team': ['Lakers', 'Suns', 'Warriors', 'Nuggets', '76ers', 'Mavericks', 'Bucks', 'Celtics'],
    'Position': ['F', 'F', 'G', 'C', 'C', 'G', 'G', 'F'],
    'PPG': [28.9, 29.1, 29.4, 24.5, 33.1, 32.4, 32.2, 30.1], # 경기당 득점
    'RPG': [8.3, 6.7, 6.1, 11.8, 10.2, 8.6, 5.7, 8.8], # 경기당 리바운드
    'APG': [6.8, 5.0, 6.3, 9.8, 4.2, 8.0, 7.3, 4.6], # 경기당 어시스트
    'Salary': [44.5, 44.1, 48.1, 33.0, 33.6, np.nan, 42.5, 30.4] # 연봉 (백만 달러)
}
df_nba = pd.DataFrame(data)

# 1. 데이터 탐색 및 정제
# avg_points = df_nba[df_nba['Position'] == 'G']['Salary'].mean()
# df_nba['Salary'] = df_nba['Salary'].fillna(avg_points)

# 2. 데이터 분석 (그룹화 및 필터링)
# avg_ppg = df_nba.groupby('Position')[['PPG', 'RPG', 'APG']].mean()
# elite_scorer = df_nba[(df_nba['PPG'] >= 30) & (df_nba['APG'] >= 5.0)]

# 3. 통계 및 시각화
# materix = df_nba[['PPG', 'RPG', 'APG', 'Salary']]

# sns.barplot(x='Position', y='PPG', data=df_nba)
# plt.show()

# sns.scatterplot(x='PPG', y='Salary', data=materix)
# plt.show()

# 1. 데이터 탐색 및 정제
# print(df_nba.info())
# print(df_nba)

# 2. 데이터 분석 (그룹화 및 필터링)
# print(avg_ppg)
# print(elite_scorer)

# 3. 통계 및 시각화
# print(materix.corr())
