# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {
    'Player': ['Jordan', 'Pippen', 'Rodman', 'Malone', 'Stockton', 'Jordan', 'Pippen', 'Rodman', 'Malone'],
    'Team': ['Bulls', 'Bulls', 'Bulls', 'Jazz', 'Jazz', 'Bulls', 'Bulls', 'Bulls', 'Jazz'],
    'Position': ['Guard', 'Forward', 'Forward', 'Forward', 'Guard', 'Guard', 'Forward', 'Forward', 'Forward'],
    'Points': [35, 22, 5, 28, 15, 31, 19, np.nan, 25],
    'Opponent': ['Jazz', 'Jazz', 'Jazz', 'Bulls', 'Bulls', 'Sonics', 'Sonics', 'Sonics', 'Sonics']
}
df_nba = pd.DataFrame(data)

# 2. 데이터 정제
# rodman_mean = df_nba[df_nba['Player'] == 'Rodman']['Points'].mean()
# df_nba['Points'] = df_nba['Points'].fillna(rodman_mean)

# 3. 데이터 분석 (그룹화)
# avg_points_team = df_nba.groupby('Team')['Points'].mean()
# avg_points_position = df_nba.groupby('Position')['Points'].mean()

# 4. 시각화
# total_points = df_nba.groupby('Team')['Points'].sum().reset_index()

# sns.barplot(x='Team', y='Points', data=df_nba)
# plt.show()

# sns.boxplot(x='Position', y='Points', data=df_nba)
# plt.show()


# 1. 초기 데이터 탐색
# print(df_nba.head())
# print(df_nba.info())
# print(df_nba.describe())

# 2. 데이터 정제
# print(df_nba)

# 3. 데이터 분석 (그룹화)
# print(avg_points_team)
# print(avg_points_position)
